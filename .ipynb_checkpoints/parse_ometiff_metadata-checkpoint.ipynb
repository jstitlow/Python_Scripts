# %%
# Parse OMETIFF metadata using Python XML tools
#
# TODO: 
# 
# - separate data into directories based on their channel arrangement and microscope
# - find pixel size data in the xml structure

import os
import pandas as pd
from PIL import Image
from xml.etree.ElementTree import fromstring, ElementTree # from https://stackoverflow.com/questions/33962620/elementtree-returns-element-instead-of-elementtree/44483259

# specify directory of images
#indir = ('/Users/joshtitlow/tmp/screen_data/')
indir = ('/Volumes/bioc1301/src/OMERO_scripts/OMERO_Figure_screen_dataset/CNS_figures/davisgroup//')
infiles = os.listdir(indir)

# create a df and a list to store filename and channel info
df = pd.DataFrame()
filename = []
original_file = []
ch1 = []
ch2 = []
ch3 = []
ch4 = []
xy_pix = []
z_pix = []

# functions to extract microscope data from specific types of files
def ometiff_files():
    # get channel information
    try:
        for key, value in root[0][1][0].attrib.items():                     
            if key == 'Name':
                ch1_value = value
        for key, value in root[0][1][1].attrib.items():                     
            if key == 'Name':
                ch2_value = value
        for key, value in root[0][1][2].attrib.items():                     
            if key == 'Name':
                ch3_value = value
        for key, value in root[0][1][3].attrib.items():                     
            if key == 'Name':
                ch4_value = value
            if key == 'PlaneCount':
                ch4_value = '0'
    except:   
        for key, value in root[0][2][0].attrib.items():                     
            if key == 'Name':
                ch1_value = value
        for key, value in root[0][2][1].attrib.items():                     
            if key == 'Name':
                ch2_value = value
        for key, value in root[0][2][2].attrib.items():                     
            if key == 'Name':
                ch3_value = value
        for key, value in root[0][2][3].attrib.items():                     
            if key == 'Name':
                ch4_value = value
            if key == 'PlaneCount':
                ch4_value = '0'
                
    # get pixel size
    for key, value in root[0][1].attrib.items():
        if key == 'PhysicalSizeY':
            xy_pix_value = value
    if 'PhysicalSizeY' not in root[0][1].attrib.keys():
         for key, value in root[0][2].attrib.items():
                if key == 'PhysicalSizeY':
                    xy_pix_value = value
    for key, value in root[0][1].attrib.items():
        if key == 'PhysicalSizeZ':
            z_pix_value = value
    if 'PhysicalSizeZ' not in root[0][1].attrib.keys():
         for key, value in root[0][2].attrib.items():
                if key == 'PhysicalSizeZ':
                    z_pix_value = value
            
    # append metadata to list
    filename.append(file)
    original_file.append(orig_file)
    ch1.append(ch1_value)
    ch2.append(ch2_value)
    ch3.append(ch3_value)
    ch4.append(ch4_value)
    xy_pix.append(xy_pix_value)
    z_pix.append(z_pix_value)
    print file, orig_file, ch1_value, ch2_value, ch3_value, ch4_value, xy_pix_value, z_pix_value
    
def Olympus_oir_files():
    # get channel information
    try:
        for key, value in root[0][2][0].attrib.items():                     
            if key == 'ExcitationWavelength':
                ch1_value = value
        for key, value in root[0][2][1].attrib.items():                     
            if key == 'ExcitationWavelength':
                ch2_value = value
        for key, value in root[0][2][2].attrib.items():                     
            if key == 'ExcitationWavelength':
                ch3_value = value
        for key, value in root[0][2][3].attrib.items():                     
            if key == 'ExcitationWavelength':
                ch4_value = value
        if 'ExcitationWavelength' not in root[0][2][3].attrib.keys():
             ch4_value = '0'
    except:
        for key, value in root[0][3][0].attrib.items():                     
            if key == 'ExcitationWavelength':
                ch1_value = value
        for key, value in root[0][3][1].attrib.items():                     
            if key == 'ExcitationWavelength':
                ch2_value = value
        for key, value in root[0][3][2].attrib.items():                     
            if key == 'ExcitationWavelength':
                ch3_value = value
        for key, value in root[0][3][3].attrib.items():                     
            if key == 'ExcitationWavelength':
                ch4_value = value
        if 'ExcitationWavelength' not in root[0][3][3].attrib.keys():
             ch4_value = '0'
                
    # get pixel size
    for key, value in root[0][2].attrib.items():
        if key == 'PhysicalSizeY':
            xy_pix_value = value
    if 'PhysicalSizeY' not in root[0][2].attrib.keys():
        for key, value in root[0][3].attrib.items():   
            if key == 'PhysicalSizeY':
                xy_pix_value = value
    
    for key, value in root[0][2].attrib.items():
        if key == 'PhysicalSizeZ':
            z_pix_value = value
    if 'PhysicalSizeZ' not in root[0][2].attrib.keys():
        for key, value in root[0][3].attrib.items():   
            if key == 'PhysicalSizeZ':
                z_pix_value = value
                    
    # append metadata to list
    filename.append(file)
    original_file.append(orig_file)
    ch1.append(ch1_value)
    ch2.append(ch2_value)
    ch3.append(ch3_value)
    ch4.append(ch4_value)
    xy_pix.append(xy_pix_value)
    z_pix.append(z_pix_value)
    print file, orig_file, ch1_value, ch2_value, ch3_value, ch4_value, xy_pix_value, z_pix_value

def Zeiss_czi_files():
    
    # get channel information
    for key, value in root[0][1][0].attrib.items():                     
        if key == 'ExcitationWavelength':
            ch1_value = value
    for key, value in root[0][1][1].attrib.items():                     
        if key == 'ExcitationWavelength':
            ch2_value = value
    for key, value in root[0][1][2].attrib.items():                     
        if key == 'ExcitationWavelength':
            ch3_value = value
    for key, value in root[0][1][3].attrib.items():                     
        if key == 'ExcitationWavelength':
            ch4_value = value
        if key == 'PlaneCount':
            ch4_value = '0'
                              
    # get pixel size
    for key, value in root[0][1].attrib.items():
        if key == 'PhysicalSizeY':
            xy_pix_value = value
    if 'PhysicalSizeY' not in root[0][1].attrib.keys():
         xy_pix_value = '0.5'        
                    
    for key, value in root[0][1].attrib.items():
        if key == 'PhysicalSizeZ':
            z_pix_value = value
            
    # append metadata to list
    filename.append(file)
    original_file.append(orig_file)
    ch1.append(ch1_value)
    ch2.append(ch2_value)
    ch3.append(ch3_value)
    ch4.append(ch4_value)
    xy_pix.append(xy_pix_value)
    z_pix.append(z_pix_value)
    print file, orig_file, ch1_value, ch2_value, ch3_value, ch4_value, xy_pix_value, z_pix_value

# analyse each file in the directory
for file in infiles: 
    if file.endswith('.tiff'):
        if not file.startswith('._'):
            
            # open the image and retrieve metadata
            im = Image.open(os.path.join(indir, file))
            xml = str(im.tag[270])
            #print 'getting channel info from:', file
            
            # remove extra characters that mess up xml functions
            xml = xml[3:-3]
            
            # parse the xml data
            tree = ElementTree(fromstring(xml))
            root = tree.getroot() 
                
            # get the original file name
            for key, value in root[0].attrib.items():
                if key == 'Name':
                    orig_file = value 
    
            # parse metadata based on file type
            if orig_file.endswith('.oir'):
                Olympus_oir_files()

            if orig_file.endswith('.czi'):
                Zeiss_czi_files()

            if orig_file.endswith('.ome.tiff'):
                ometiff_files()

            if '.mvd2' in orig_file:
                ometiff_files()
        
# save the data to .csv file
df['filename'] = filename
df['original_file'] = original_file       
df['ch1'] = ch1
df['ch2'] = ch2
df['ch3'] = ch3
df['ch4'] = ch4
df['xy_pix'] = xy_pix
df ['z_pix'] = z_pix
df.to_csv('smFISHscreen_metadata.csv', index=False)
# Out:
# 382793.ome.tiff 2017oct17_001430(kat80)_20x_YFP_DLG_syp_test1overview2%lasers.czi 405.00000000000006 561.0 488.00000000000006 0 1.037832280124744 3.0
# 390478.ome.tiff 2017oct23_001180(BNIP3)_control_60x_CB_DAPI_syp_DLG_YFP.oir 420.0 650.0 570.0 500.0 0.414320379601492 1.5
# 390479.ome.tiff 2017oct23_001180(BNIP3)_control_60x_MB_DAPI_syp_DLG_YFP.oir 420.0 650.0 570.0 500.0 0.414320379601492 1.5
# 390480.ome.tiff 2017oct23_001180(BNIP3)_control_60x_OL_DAPI_syp_DLG_YFP.oir 420.0 650.0 570.0 500.0 0.414320379601492 1.5
# 390483.ome.tiff 2017oct23_001180(BNIP3)_test2_20x_DAPI_syp_DLG_YFP.oir 420.0 570.0 500.0 0 1.242961138804478 3.0
# 390484.ome.tiff 2017oct23_001180(BNIP3)_test2_60x_CB_DAPI_syp_DLG_YFP.oir 420.0 650.0 570.0 500.0 0.414320379601492 1.5
# 390486.ome.tiff 2017oct23_001180(BNIP3)_test2_60x_MB_DAPI_syp_DLG_YFP_0001.oir 420.0 650.0 570.0 500.0 0.414320379601492 1.5
# 390487.ome.tiff 2017oct23_001180(BNIP3)_test2_60x_OL_DAPI_syp_DLG_YFP.oir 420.0 650.0 570.0 500.0 0.414320379601492 1.5
# 390989.ome.tiff 2017oct25_001580(Pka-R2)_control_60x_CB_DAPI_syp_DLG_YFP_lowerlaser_0001.oir 420.0 650.0 570.0 500.0 0.414320379601492 1.5
# 390990.ome.tiff 2017oct25_001580(Pka-R2)_control_60x_MB_DAPI_syp_DLG_YFP_lowerlaser.oir 420.0 650.0 570.0 500.0 0.414320379601492 1.5
# 390991.ome.tiff 2017oct25_001580(Pka-R2)_control_60x_OL_DAPI_syp_DLG_YFP_lowerlaser.oir 420.0 650.0 570.0 500.0 0.414320379601492 1.5
# 390992.ome.tiff 2017oct25_001580(Pka-R2)_control_60x_VNC_DAPI_syp_DLG_YFP_lowerlaser.oir 420.0 650.0 570.0 500.0 0.414320379601492 1.5
# 390994.ome.tiff 2017oct25_001580(Pka-R2)_test_20x_DAPI_syp_DLG_YFP_lowerlaser.oir 420.0 570.0 500.0 0 1.242961138804478 3.0
# 390995.ome.tiff 2017oct25_001580(Pka-R2)_test_60x_CB_DAPI_syp_DLG_YFP_lowerlaser.oir 420.0 650.0 570.0 500.0 0.414320379601492 1.5
# 390996.ome.tiff 2017oct25_001580(Pka-R2)_test_60x_MB_DAPI_syp_DLG_YFP_lowerlaser.oir 420.0 650.0 570.0 500.0 0.414320379601492 1.5
# 390997.ome.tiff 2017oct25_001580(Pka-R2)_test_60x_OL_DAPI_syp_DLG_YFP_lowerlaser.oir 420.0 650.0 570.0 500.0 0.414320379601492 1.5
# 390998.ome.tiff 2017oct25_001580(Pka-R2)_test_60x_VNC_DAPI_syp_DLG_YFP_lowerlaser.oir 420.0 650.0 570.0 500.0 0.414320379601492 1.5
# 392276.ome.tiff 2017oct31_001056(CG15307)_control_60x_CB_DAPI_syp_DLG_YFP.oir 420.0 650.0 570.0 500.0 0.414320379601492 1.5
# 392278.ome.tiff 2017oct31_001056(CG15307)_control_60x_OL_DAPI_syp_DLG_YFP.oir 420.0 650.0 570.0 500.0 0.414320379601492 1.5
# 392280.ome.tiff 2017oct31_001056(CG15307)_test_20x_DAPI_syp_DLG_YFP.oir 420.0 570.0 500.0 0 1.242961138804478 3.0
# 392281.ome.tiff 2017oct31_001056(CG15307)_test_60x_CB_DAPI_syp_DLG_YFP.oir 420.0 650.0 570.0 500.0 0.414320379601492 1.5
# 392282.ome.tiff 2017oct31_001056(CG15307)_test_60x_MB_DAPI_syp_DLG_YFP.oir 420.0 650.0 570.0 500.0 0.414320379601492 1.5
# 392283.ome.tiff 2017oct31_001056(CG15307)_test_60x_OL_DAPI_syp_DLG_YFP.oir 420.0 650.0 570.0 500.0 0.414320379601492 1.5
# 400669.ome.tiff 20171111 sd.mvd2 [20171111_CPTI_14-3-3-epsilon_OL_dorsal_60x] DAPI GFP RFP Cy5 0.13888805165151769 0.5
# 400670.ome.tiff 20171111 sd.mvd2 [20171111_CPTI_14-3-3-epsilon_AL_dorsal_60x] DAPI GFP RFP Cy5 0.13888805165151769 0.5
# 400671.ome.tiff 20171111 sd.mvd2 [20171111_CPTI_14-3-3-epsilon_MB_dorsal_60x] DAPI GFP RFP Cy5 0.13888805165151769 0.5
# 400672.ome.tiff 20171111 sd.mvd2 [20171111_CPTI_14-3-3-epsilon_MB_ventral_60x] DAPI GFP RFP Cy5 0.13888805165151769 0.5
# 400673.ome.tiff 20171111 sd.mvd2 [20171111_CPTI_14-3-3-epsilon_VNC_ventral_60x] DAPI GFP RFP Cy5 0.13888805165151769 0.5
# 400674.ome.tiff 20171111 sd.mvd2 [20171111_OrR_CPTI_14-3-3-epsilon_OL_dorsal_60x] DAPI GFP RFP Cy5 0.13888805165151769 0.5
# 400675.ome.tiff 20171111 sd.mvd2 [20171111_OrR_CPTI_14-3-3-epsilon_AL_dorsal_60x] DAPI GFP RFP Cy5 0.13888805165151769 0.5
# 400676.ome.tiff 20171111 sd.mvd2 [20171111_OrR_CPTI_14-3-3-epsilon_MB_dorsal_60x] DAPI GFP RFP Cy5 0.13888805165151769 0.5
# 400677.ome.tiff 20171111 sd.mvd2 [20171111_OrR_CPTI_14-3-3-epsilon_MB_ventral_60x] DAPI GFP RFP Cy5 0.13888805165151769 0.5
# 400678.ome.tiff 20171111 sd.mvd2 [20171111_OrR_CPTI_14-3-3-epsilon_VNC_dorsal_60x] DAPI GFP RFP Cy5 0.13888805165151769 0.5
# 402006.ome.tiff 2017nov13_000609(Elf)_test_60x_CB_NBs_1024_DAPI_syp_DLG_YFP.oir 420.0 650.0 570.0 500.0 0.207160189800746 1.5
#
60x.oir 570.0 640.0 410.0 490.0 0.103580094900373 1.5
# 530057.ome.tiff 20072018_CPTI-100012_CG1648_DAPI_syp_venusYFP_MBcalyx_dorsal_60x.oir 570.0 640.0 410.0 490.0 0.103580094900373 1.0
# 530058.ome.tiff 20072018_CPTI-100012_CG1648_DAPI_syp_venusYFP_VNC_dorsal_60x.oir 570.0 640.0 410.0 490.0 0.103580094900373 1.5
# 530059.ome.tiff 20072018_CPTI-100012_CG1648_DAPI_syp_venusYFP_overview_dorsal_20x.oir 570.0 410.0 490.0 0 0.621480569402239 3.0
# 540320.ome.tiff 31072018_CPTI-000033_CG42342_DAPI_syp_venusYFP_overview_dorsal_20x.oir 570.0 410.0 490.0 0 0.621480569402239 3.0
# 579642.ome.tiff g1_overview_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0
# 579643.ome.tiff g2_overview_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0
# 579644.ome.tiff g3_overview_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0
# 579645.ome.tiff g3_overview_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0
# 579646.ome.tiff g2_overview_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0
# 579647.ome.tiff g1_overview_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0
# 579648.ome.tiff g4_overview_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0
# 579650.ome.tiff g4_overview_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0
# 579651.ome.tiff g2_overview_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0
# 579652.ome.tiff g1_overview_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0
# 579653.ome.tiff g3_overview_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0
# 579655.ome.tiff g3_overview_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0
# 579656.ome.tiff g2_overview_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0
# 579658.ome.tiff g4_overview_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0
# 579659.ome.tiff g1_overview_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0
# 579661.ome.tiff g4_overview_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0
# 579662.ome.tiff g1_overview_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0
# 579664.ome.tiff g2_overview_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0
# 584882.ome.tiff 05Sep_Eif4A_CPTI002562_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0
# 584982.ome.tiff 05Sep_Eif4A_CPTI002562_60x_Lobe.oir 430.0 650.0 500.0 570.0 0.103580094900373 1.0
# 584983.ome.tiff 05Sep_Eif4A_CPTI002562_60x_WholeLobe.oir 430.0 650.0 500.0 570.0 0.103580094900373 1.0
# 598888.ome.tiff 0774_overview_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0
# 598889.ome.tiff 0038_overview_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0
# 598890.ome.tiff 2905_overview_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0
# 598891.ome.tiff 1409_overview_20x.oir 430.0 500.0 570.0 0 0.621480569402239 3.0

# %%
root[0][3].attrib
# Out:
# {'DimensionOrder': 'XYZCT',
#  'ID': 'urn:lsid:export.openmicroscopy.org:Pixels:7637023b-3f61-416e-97c6-be8ea199b758_414815:19742701',
#  'PhysicalSizeX': '0.621480569402239',
#  'PhysicalSizeXUnit': '\\xc2\\xb5m',
#  'PhysicalSizeY': '0.621480569402239',
#  'PhysicalSizeYUnit': '\\xc2\\xb5m',
#  'PhysicalSizeZ': '3.0',
#  'PhysicalSizeZUnit': '\\xc2\\xb5m',
#  'SizeC': '3',
#  'SizeT': '1',
#  'SizeX': '1024',
#  'SizeY': '1024',
#  'SizeZ': '13',
#  'Type': 'uint16'}

# %%
if 'PhysicalSizeY' in root[0][1].attrib.keys():
    print 'yes'
else: 
    print 'no'
# Out:
# yes

# %%
root[0][2][0].attrib
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-124-e16a3ec0049c> in <module>()
# ----> 1 root[0][2][0].attrib
#
# //anaconda/lib/python2.7/xml/etree/ElementTree.pyc in __getitem__(self, index)
#     264
#     265     def __getitem__(self, index):
# --> 266         return self._children[index]
#     267
#     268     ##
#
# IndexError: list index out of range

# %%
for key, value in root[0][2][3].attrib.items():                     
    if key == 'ExcitationWavelength':
        ch4_value = value
    if key == 'PlaneCount':
        ch4_value = '0'
print ch4_value
# Out:
# 570.0

# %%
root[0][1].attrib
# Out:
# {'DimensionOrder': 'XYZCT',
#  'ID': 'urn:lsid:export.openmicroscopy.org:Pixels:7637023b-3f61-416e-97c6-be8ea199b758_171648:7193822',
#  'PhysicalSizeZ': '0.35',
#  'PhysicalSizeZUnit': '\\xc2\\xb5m',
#  'SizeC': '4',
#  'SizeT': '1',
#  'SizeX': '512',
#  'SizeY': '512',
#  'SizeZ': '158',
#  'Type': 'uint16'}

# %%
root[0][1].attrib
# Out:
# {}

# %%
# This is the standard xml architecture
# requires the extracted xml string to be saved as a document and parsed with ET.parse
# because of issue with ET.fromstring, explained here: https://stackoverflow.com/questions/33962620/elementtree-returns-element-instead-of-elementtree/44483259

from PIL import Image
import xml.etree.cElementTree as ET

im = Image.open('/Volumes/bioc1301/src/OMERO_scripts/OMERO_Figure_screen_dataset/CNS_figures/mRNAlocalisation/547914.ome.tiff')
xml = str(im.tag[270])
xml = xml[3:-3]
xml_doc = '/Users/joshtitlow/Desktop/xml.xml'
with open(xml_doc, 'w') as fp:
    fp.write(xml)
tree = ET.parse(xml_doc)
#tree = ET.fromstring(xml)
root = tree.getroot()

try:
    for key, value in root[0][1][0].attrib.items():
        #print key,':', value
        if key == 'ExcitationWavelength':
            ch1 = value
    for key, value in root[0][1][1].attrib.items():
        #print key,':', value
        if key == 'ExcitationWavelength':
            ch2 = value
    for key, value in root[0][1][2].attrib.items():
        #print key,':', value
        if key == 'ExcitationWavelength':
            ch3 = value
    for key, value in root[0][1][3].attrib.items():
        #print key,':', value
        if key == 'ExcitationWavelength':
            ch4 = value
except:
    try: 
        for key, value in root[0][2][0].attrib.items():
            #print key,':', value
            if key == 'ExcitationWavelength':
                ch1 = value
        for key, value in root[0][2][1].attrib.items():
            #print key,':', value
            if key == 'ExcitationWavelength':
                ch2 = value
        for key, value in root[0][2][2].attrib.items():
            #print key,':', value
            if key == 'ExcitationWavelength':
                ch3 = value
        for key, value in root[0][2][3].attrib.items():
            #print key,':', value
            if key == 'ExcitationWavelength':
                ch4 = value
    except:
        pass

print file, orig_file, ch1_value, ch2_value, ch3_value, ch4_value, xy_pix_value, z_pix_value
# Out:
# 547914.ome.tiff 20180810_OrR_VNC.ome.tiff Far-Red 7
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-93-f37ad831ee49> in <module>()
#      54         pass
#      55
# ---> 56 print file, orig_file, ch1_value, ch2_value, ch3_value, ch4_value, xy_pix_value, z_pix_value
#
# NameError: name 'ch2_value' is not defined

# %%
for key, value in root[0][1][2].attrib.items():
    print key, ',', value
# Out:
# Name , Ch1-T3
# AcquisitionMode , LaserScanningConfocalMicroscopy
# Color , 65535
# SamplesPerPixel , 1
# EmissionWavelengthUnit , nm
# ExcitationWavelength , 405.00000000000006
# ExcitationWavelengthUnit , nm
# IlluminationType , Epifluorescence
# Fluor , DAPI
# EmissionWavelength , 461.50000000000006
# ID , urn:lsid:export.openmicroscopy.org:Channel:7637023b-3f61-416e-97c6-be8ea199b758_334075:7253760

# %%
for key, value in root[0][2].attrib.items():
    if key == 'PhysicalSizeY':
        print value
# Out:
# SizeT
# DimensionOrder
# PhysicalSizeY
# PhysicalSizeX
# PhysicalSizeZ
# SizeX
# PhysicalSizeZUnit
# SizeZ
# SizeY
# PhysicalSizeXUnit
# SizeC
# Type
# ID
# PhysicalSizeYUnit

# %%
root[0].attrib
# Out:
# {'ID': 'urn:lsid:export.openmicroscopy.org:Image:7637023b-3f61-416e-97c6-be8ea199b758_390478:15827246',
#  'Name': '2017oct23_001180(BNIP3)_control_60x_CB_DAPI_syp_DLG_YFP.oir'}

# %%
for key, value in root[0][1][3].attrib.items():
    print key
# Out:
# IFD
# PlaneCount
# FirstZ
# FirstC
# FirstT

# %%
# This is the standard xml architecture
# requires the extracted xml string to be saved as a document and parsed with ET.parse
# because of issue with ET.fromstring, explained here: https://stackoverflow.com/questions/33962620/elementtree-returns-element-instead-of-elementtree/44483259

from PIL import Image
import xml.etree.cElementTree as ET

im = Image.open('/Users/joshtitlow/tmp/screen_data/382793.ome.tiff')
xml = str(im.tag[270])
xml = xml[3:-3]
xml_doc = '/Users/joshtitlow/Desktop/xml.xml'
with open(xml_doc, 'w') as fp:
    fp.write(xml)
tree = ET.parse(xml_doc)
#tree = ET.fromstring(xml)
root = tree.getroot()

for key, value in root[0][1][0].attrib.items():
    #print key,':', value
    if key == 'ExcitationWavelength':
        ch1 = value
for key, value in root[0][1][1].attrib.items():
    #print key,':', value
    if key == 'ExcitationWavelength':
        ch2 = value
for key, value in root[0][1][2].attrib.items():
    #print key,':', value
    if key == 'ExcitationWavelength':
        ch3 = value
        
print ch1, ch2, ch3
# Out:
# 405.00000000000006 561.0 488.00000000000006

# %%
root[0][1][0].attrib
# Out:
# {'AcquisitionMode': 'LaserScanningConfocalMicroscopy',
#  'Color': '65535',
#  'EmissionWavelength': '446.12408800000003',
#  'EmissionWavelengthUnit': 'nm',
#  'ExcitationWavelength': '405.00000000000006',
#  'ExcitationWavelengthUnit': 'nm',
#  'ID': 'urn:lsid:export.openmicroscopy.org:Channel:7637023b-3f61-416e-97c6-be8ea199b758_820492:15525066',
#  'IlluminationType': 'Epifluorescence',
#  'Name': 'ChS1-T1',
#  'SamplesPerPixel': '1'}

# %%
for key, value in root[0][0][1][0].attrib.items():
    #print key,':', value
    if key == 'excitationwavelength':
        ch1 = value
for key, value in root[0][0][1][1].attrib.items():
    #print key,':', value
    if key == 'excitationwavelength':
        ch2 = value
for key, value in root[0][0][1][2].attrib.items():
    #print key,':', value
    if key == 'excitationwavelength':
        ch3 = value
print ch1, ch2, ch3

# %%
root[0][1][0][0][0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-237-e2fb17db9668> in <module>()
# ----> 1 root[0][1][0][0][0]
#
# IndexError: child index out of range

# %%
tree = ET.parse('/Users/joshtitlow/Desktop/items.xml')
root = tree.getroot()
for key, value in root.getitems:
    print key, ':', value
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-244-001dd0436003> in <module>()
#       1 tree = ET.parse('/Users/joshtitlow/Desktop/items.xml')
#       2 root = tree.getroot()
# ----> 3 for key, value in root.getitems:
#       4     print key, ':', value
#
# AttributeError: getitems
