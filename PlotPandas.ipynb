# %%
import seaborn as sns #seaborn is a Python library that builds on Matplotlib functionality
import pandas as pd #Pandas is for handling spreadsheet data
import matplotlib.pyplot as plt #matplotlib is for plotting

# %matplotlib inline 
#magic function that enables plot display in notebook

data = pd.read_excel('DiffData1.xlsx') #read in the data

df=pd.DataFrame(data) #make a dataframe for analysis

sns.set_style("white") #gives white style
sns.set_style("ticks") #adds tick marks everywhere


ax = sns.boxplot(data=data) #create box plot with data
ax = sns.swarmplot(data=data, color=".25") #show the data points with jitter


ax.set_ylabel('tau (ms)', fontsize=14) #add y-axis label and make it 14pt
#ax.set_title('Nucleus', fontsize=14) #add title and make it 14pt
ax=sns.despine() #take away top and right axes

# Get current size
fig_size = plt.rcParams["figure.figsize"]
 
# Prints: [8.0, 6.0]
 
# Set figure width to 12 and height to 9
fig_size[0] = 12
fig_size[1] = 3
plt.rcParams["figure.figsize"] = fig_size

print "Current size:", fig_size
# Out:
# Current size: [12, 3]

# %%
import pandas as pd

left = pd.read_csv('/Users/joshtitlow/Google Drive File Stream/Davis_Lab/smFISH_Screen/Datasets/Bayes_2012_pOne.csv')
right = pd.read_csv('/Users/joshtitlow/Desktop/DavidGUI/data/raw-metadata.csv')
merge = pd.merge(left, right, how='left', on=['OMERO_Figure_ID'])

merge.to_csv('/Users/joshtitlow/Desktop/DavidGUI/merge.csv')

# %%
import pandas as pd

left = pd.read_csv('/Users/joshtitlow/Google Drive File Stream/My Drive/Davis_Lab/smFISH_Screen/Datasets/Bayes_2012_pOne.csv')
right = pd.read_csv('/Users/joshtitlow/Google Drive File Stream/My Drive/Davis_Lab/smFISH_Screen/Datasets/Ensembl_mouse_to_fly.csv')
merge = pd.merge(left, right, how='left', on=['Ensembl_mouse'])

merge.to_csv('/Users/joshtitlow/Google Drive File Stream/My Drive/Davis_Lab/smFISH_Screen/Datasets/PSD_proteome.csv')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

a = np.random.normal(0,2,1000)
b = np.random.normal(-2,7,1000)
data = [a,b]


plt.boxplot(data) # Or you can use the boxplot from Pandas

for i in [1,2]:
    y = data[i-1]
    x = np.random.normal(i, 0.02, len(y))
    plt.plot(x, y, 'r.', alpha=0.2)
    
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_excel('DiffData.xlsx')

df=pd.DataFrame(data)

data = [0,1]


df.boxplot(data) # Or you can use the boxplot from Pandas

for i in [1,2]:
    y = data[i-1]
    x = (i, 0.02, len(y))
    plt.plot(x, y, 'r.', alpha=0.2)
    
plt.show()
# Out:
# /Users/joshtitlow/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:13: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-7c9506d1f689> in <module>()
#      15 for i in [1,2]:
#      16     y = data[i-1]
# ---> 17     x = np.random.normal(i, 0.02, len(y))
#      18     plt.plot(x, y, 'r.', alpha=0.2)
#      19
#
# TypeError: object of type 'int' has no len()

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_excel('DiffData.xlsx')

df=pd.DataFrame(data)

#for i in [1,2]:
#    y = data[i-1]
#    x = np.random.normal(i, 0.02, len(y))
#    plt.plot(x, y, 'r.', alpha=0.2)

color = dict(boxes='DarkGreen', whiskers='DarkOrange', medians='DarkBlue', caps='Gray')
df.plot.box(color=color, sym='r+')
